# %% [markdown]
# # Exercise 1

# %% [markdown]
# # Problem 1

# %%
ice_cream_rating=7

# %%
sleeping_rating=9

# %% [markdown]
# # Problem 2

# %%
first_name=input('What is your first name? ')
# Out:
# What is your first name?  Gabriela

# %%
last_name=input('What is your last name?')
# Out:
# What is your last name? Sierra

# %%
x=' '

# %%
my_name=first_name+ x +last_name

# %%
print(my_name)
# Out:
# Gabriela Sierra

# %% [markdown]
# # Problem 3

# %%
hapiness_rating=(ice_cream_rating+sleeping_rating)/2

# %%
print (ice_cream_rating,sleeping_rating,hapiness_rating)
# Out:
# 7 9 8.0

# %%
y=type(ice_cream_rating)

# %%
z=type(first_name)

# %%
w=type(hapiness_rating)

# %%
print(y,z,w)
# Out:
# <class 'int'> <class 'str'> <class 'float'>

# %%
print('My name is', first_name, 'and I give eating ice cream a score of', ice_cream_rating, 'out of 10!')
# Out:
# My name is Gabriela and I give eating ice cream a score of 7 out of 10!

# %%
print('I am' , my_name, 'and my sleeping enjoyment rating is', sleeping_rating, '/ 10!')
# Out:
# I am Gabriela Sierra and my sleeping enjoyment rating is 9 / 10!
